# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandreBourrieau/ML/blob/main/ML/Carnets%20Jupyter/S%C3%A9ries%20temporelles/Analyse_Stationnarit%C3%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %%
import sys
import pandas

# %% [markdown]
# # Méthodes permettant de vérifier la non stationnarité des séries temporelles

# %% [markdown]
# **1. Exemple d'une série non stationnaire**

# %% [markdown]
# L'exemple ci-dessous montre ...

# %%
# !wget --no-check-certificate --content-disposition "https://raw.githubusercontent.com/AlexandreBourrieau/ML/main/Carnets%20Jupyter/S%C3%A9ries%20temporelles/data/daily-total-female-births-in-cal.csv"
# !wget --no-check-certificate --content-disposition "https://raw.githubusercontent.com/AlexandreBourrieau/ML/main/Carnets%20Jupyter/S%C3%A9ries%20temporelles/data/international-airline-passengers.csv"
# Out:
# --2021-04-08 11:16:29--  https://raw.githubusercontent.com/AlexandreBourrieau/ML/main/Carnets%20Jupyter/S%C3%A9ries%20temporelles/data/daily-total-female-births-in-cal.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6312 (6.2K) [text/plain]
# Saving to: ‘daily-total-female-births-in-cal.csv.1’
#
# daily-total-female- 100%[===================>]   6.16K  --.-KB/s    in 0s
#
# 2021-04-08 11:16:29 (42.6 MB/s) - ‘daily-total-female-births-in-cal.csv.1’ saved [6312/6312]
#
# --2021-04-08 11:16:29--  https://raw.githubusercontent.com/AlexandreBourrieau/ML/main/Carnets%20Jupyter/S%C3%A9ries%20temporelles/data/international-airline-passengers.csv
# ...

# %%
from pandas import Series
from pandas import read_csv

from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Charge les données en mémoire
fichier1 = 'daily-total-female-births-in-cal.csv'
fichier2 = 'international-airline-passengers.csv'

serie1 = read_csv(fichier1, usecols=[1], engine='python', skipfooter=2)
serie2 = read_csv(fichier2, usecols=[1], engine='python', skipfooter=2)

data1 = serie1.values
data1 = data1.astype('float32')

data2 = serie2.values
data2 = data2.astype('float32')

# Affiche les données
f1, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
f1.tight_layout()

serie1.plot(subplots=True, ax=ax1, legend=False, sharex=False, sharey=False)
ax1.set_title('daily-total-female-births')

serie2.plot(subplots=True, ax=ax2, legend=False, sharex=False, sharey=False)
ax2.set_title('international-airline-passengers')
# Out:
# Text(0.5, 1.0, 'international-airline-passengers')
